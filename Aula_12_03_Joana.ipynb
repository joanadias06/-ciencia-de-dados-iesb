# %% [markdown]
# <a href="https://colab.research.google.com/github/joanadias06/-ciencia-de-dados-iesb/blob/main/Aula_12_03_Joana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Word")
# Out:
# Hello Word

# %%
print(input("Informe o seu nome: "))
print(input("Informe a sua idade: "))
# Out:
# Informe o seu nome: Joana
# Joana
# Informe a sua idade: 20
# 20

# %%
data_nascimento = int(input("Informe o Ano que você masceu  "))
ano = 2026 - data_nascimento

print("A sua idade para o ano de 2026 é de: ", ano)
# Out:
# Informe o Ano que você masceu  2006
# A sua idade para o ano de 2026 é de:  20
